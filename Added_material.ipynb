# %%
import json
fd = open('Records.json', 'r')
r = fd.read()
fd.close()

Record = json.loads(r)

fd = open('Sales.json', 'r')
s = fd.read()
fd.close()

sales = json.loads(s)

# %%
m=-1
while m!=0:
    m=int(input('Emter 0 for Exit and 1 for continue : '))
    if m==1:
        mat=" "
        print("Welcome to th Garry's Grocery store\n")
        mat=str(input("Are you adding old material or new(Enter old or new) : "))
            
        if mat=='old' or mat=='Old':
            print("\n1 - Fruits \n2 - Vegetables \n3 - flour \n4 - Condiments-spices \n5 - Fish-Shelfish \n6 - Baverages\n")
            n=int(input("Enter the No. as mentionned above in which section you want to add material : "))
            #Fruits
            if n==1:
                print("\n<--*--*--*--*--*--*Available products are*--*--*--*--*--*--*-->\n")
                print('ID   -  Prroduct')
                for i in Record['Fruits']:
                    print(i,' - ',Record['Fruits'][i]['Name'])
                prod_id=str(input("\nEnter the id of prodcut ......"))
                prod_qn=int(int(input("\nEnter the quantity : ")))
                Record['Fruits'][prod_id]['quantity']=Record['Fruits'][prod_id]['quantity']+prod_qn
            #Vegetables
            elif n==2:
                print("\n<--*--*--*--*--*--*Available products are*--*--*--*--*--*--*-->\n")
                print('ID   -  Prroduct')
                for i in Record['Vegetables']:
                    print(i,' - ',Record['Vegetables'][i]['Name'])
                prod_id=str(input("\nEnter the id of prodcut ......"))
                prod_qn=int(int(input("\nEnter the quantity : ")))
                Record['Vegetables'][prod_id]['quantity']=Record['Vegetables'][prod_id]['quantity']+prod_qn
            #flour
            elif n==3:
                print("\n<--*--*--*--*--*--*Available products are*--*--*--*--*--*--*-->\n")
                print('ID   -  Prroduct')
                for i in Record['flour']:
                    print(i,' - ',Record['flour'][i]['Name'])
                prod_id=str(input("\nEnter the id of prodcut ......"))
                prod_qn=int(int(input("\nEnter the quantity : ")))
                Record['flour'][prod_id]['quantity']=Record['flour'][prod_id]['quantity']+prod_qn
            #Condiments-spices
            elif n==4:
                print("\n<--*--*--*--*--*--*Available products are*--*--*--*--*--*--*-->\n")
                print('ID   -  Prroduct')
                for i in Record['Condiments-spices']:
                    print(i,' - ',Record['Condiments-spices'][i]['Name'])
                prod_id=str(input("\nEnter the id of prodcut ......"))
                prod_qn=int(int(input("\nEnter the quantity : ")))  
                Record['Condiments-spices'][prod_id]['quantity']=Record['Condiments-spices'][prod_id]['quantity']+prod_qn
            #Fish-shelfish
            elif n==5:
                print("\n<--*--*--*--*--*--*Available products are*--*--*--*--*--*--*-->\n")
                print('ID   -  Prroduct')
                for i in Record['Fish-Shelfish']:
                    print(i,' - ',Record['Fish-Shelfish'][i]['Name'])
                prod_id=str(input("\nEnter the id of prodcut ......"))
                prod_qn=int(int(input("\nEnter the quantity : ")))
                Record['Fish-Shelfish'][prod_id]['quantity']=Record['Fish-Shelfish'][prod_id]['quantity']+prod_qn
            #Baverages
            elif n==6:
                print("\n<--*--*--*--*--*--*Available products are*--*--*--*--*--*--*-->\n")
                print('ID   -  Prroduct')
                for i in Record['Baveragesh']:
                    print(i,' - ',Record['Baverages'][i]['Name'])
                prod_id=str(input("\nEnter the id of prodcut ......"))
                prod_qn=int(int(input("\nEnter the quantity : ")))
                Record['Baverages'][prod_id]['quantity']=Record['Baverages'][prod_id]['quantity']+prod_qn

        elif mat=='new' or mat=='New':
            print("\n1 - Fruits \n2 - Vegetables \n3 - flour \n4 - Condiments-spices \n5 - Fish-Shelfish \n6 - Baverages\n")
            n=int(input("Enter the No. as mentionned above in which section you want to add material : "))
            prod_name=str(input("Enter the product Name : "))
            prod_price=int(input("\nEnter the Price of each product : "))
            prod_unit=str(input("\nEnter the Unit od product : "))
            #Fruits
            if n==1:
                print("\n<--*--*--*--*--*--*Available products are*--*--*--*--*--*--*-->\n")
                print('ID   -  Prroduct')
                for i in Record['Fruits']:
                    print(i,' - ',Record['Fruits'][i]['Name'])
                prod_id=str(input("\nEnter the id of prodcut ......"))
                prod_qn=int(int(input("\nEnter the quantity : ")))
                Record['Fruits'][prod_id]={'Name':prod_name,'quantity':prod_qn,'price':prod_price,'unit':prod_unit}

            #Vegetables
            elif n==2:
                print("\n<--*--*--*--*--*--*Available products are*--*--*--*--*--*--*-->\n")
                print('ID   -  Prroduct')
                for i in Record['Vegetables']:
                    print(i,' - ',Record['Vegetables'][i]['Name'])
                prod_id=str(input("\nEnter the id of prodcut ......"))
                prod_qn=int(int(input("\nEnter the quantity : ")))
                Record['Vegetables'][prod_id]={'Name':prod_name,'quantity':prod_qn,'price':prod_price,'unit':prod_unit}
            #flour
            elif n==3:
                print("\n<--*--*--*--*--*--*Available products are*--*--*--*--*--*--*-->\n")
                print('ID   -  Prroduct')
                for i in Record['flour']:
                    print(i,' - ',Record['flour'][i]['Name'])
                prod_id=str(input("\nEnter the id of prodcut ......"))
                prod_qn=int(int(input("\nEnter the quantity : ")))
                Record['flour'][prod_id]={'Name':prod_name,'quantity':prod_qn,'price':prod_price,'unit':prod_unit}
            #Condiments-spices
            elif n==4:
                print("\n<--*--*--*--*--*--*Available products are*--*--*--*--*--*--*-->\n")
                print('ID   -  Prroduct')
                for i in Record['Condiments-spices']:
                    print(i,' - ',Record['Condiments-spices'][i]['Name'])
                prod_id=str(input("\nEnter the id of prodcut ......"))
                prod_qn=int(int(input("\nEnter the quantity : ")))  
                Record['Condiments-spices'][prod_id]={'Name':prod_name,'quantity':prod_qn,'price':prod_price,'unit':prod_unit}
            #Fish-shelfish
            elif n==5:
                print("\n<--*--*--*--*--*--*Available products are*--*--*--*--*--*--*-->\n")
                print('ID   -  Prroduct')
                for i in Record['Fish-Shelfish']:
                    print(i,' - ',Record['Fish-Shelfish'][i]['Name'])
                prod_id=str(input("\nEnter the id of prodcut ......"))
                prod_qn=int(int(input("\nEnter the quantity : ")))
                Record['Fish-shelfish'][prod_id]={'Name':prod_name,'quantity':prod_qn,'price':prod_price,'unit':prod_unit}
            #Baverages
            elif n==6:
                print("\n<--*--*--*--*--*--*Available products are*--*--*--*--*--*--*-->\n")
                print('ID   -  Prroduct')
                for i in Record['Baverages']:
                    print(i,' - ',Record['Baverages'][i]['Name'])
                prod_id=str(input("\nEnter the id of prodcut ......"))
                prod_qn=int(int(input("\nEnter the quantity : ")))
                Record['Baverages'][prod_id]={'Name':prod_name,'quantity':prod_qn,'price':prod_price,'unit':prod_unit}
        else:
            print("Please enter the correct keyword 'old' or 'new'")
# Out:
# Emter 0 for Exit and 1 for continue : 1
# Welcome to th Garry's Grocery store
#
# Are you adding old material or new(Enter old or new) : old
#
# 1 - Fruits
# 2 - Vegetables
# 3 - flour
# 4 - Condiments-spices
# 5 - Fish-Shelfish
# 6 - Baverages
#
# Enter the No. as mentionned above in which section you want to add material : 1
#
# <--*--*--*--*--*--*Available products are*--*--*--*--*--*--*-->
#
# ID   -  Prroduct
# 101  -  Bananas
# 102  -  Apples
# 103  -  Grapes
# 104  -  Oranges
# 105  -  Pineapple
#
# Enter the id of prodcut ......101
#
# Enter the quantity : 60
# Emter 0 for Exit and 1 for continue : 1
# Welcome to th Garry's Grocery store
#
# Are you adding old material or new(Enter old or new) : new
#
# 1 - Fruits
# 2 - Vegetables
# 3 - flour
# 4 - Condiments-spices
# 5 - Fish-Shelfish
# 6 - Baverages
#
# Enter the No. as mentionned above in which section you want to add material : 1
# Enter the product Name : Kiwi
#
# Enter the Price of each product : 80
#
# Enter the Unit od product : per_kg
#
# <--*--*--*--*--*--*Available products are*--*--*--*--*--*--*-->
#
# ID   -  Prroduct
# 101  -  Bananas
# 102  -  Apples
# 103  -  Grapes
# 104  -  Oranges
# 105  -  Pineapple
#
# Enter the id of prodcut ......106
#
# Enter the quantity : 70
# Emter 0 for Exit and 1 for continue : 0

# %%
Record
# Out:
# {'Fruits': {'101': {'Name': 'Bananas',
#    'quantity': 150,
#    'price': 20,
#    'unit': 'per_dozen'},
#   '102': {'Name': 'Apples', 'quantity': 150, 'price': 50, 'unit': 'per_kg'},
#   '103': {'Name': 'Grapes', 'quantity': 70, 'price': 20, 'unit': 'per_kg'},
#   '104': {'Name': 'Oranges', 'quantity': 200, 'price': 25, 'unit': 'per_kg'},
#   '105': {'Name': 'Pineapple',
#    'quantity': 50,
#    'price': 20,
#    'unit': 'per_piece'},
#   '106': {'Name': 'Kiwi', 'quantity': 70, 'price': 80, 'unit': 'per_kg'}},
#  'Vegetables': {'201': {'Name': 'Potatoes',
#    'quantity': 200,
#    'price': 20,
#    'unit': 'per_kg'},
#   '202': {'Name': 'Tomatoes', 'quantity': 197, 'price': 15, 'unit': 'per_kg'},
#   '203': {'Name': 'Onions', 'quantity': 200, 'price': 30, 'unit': 'per_kg'},
#   '204': {'Name': 'Carrots', 'quantity': 100, 'price': 25, 'unit': 'per_kg'},
#   '205': {'Name': 'Garlic', 'quantity': 100, 'price': 30, 'unit': 'per_kg'}},
#  'flour': {'301': {'Name': 'Whole Wheat flour',
#    'quantity': 500,
#    'price': 40,
#    'unit': 'per_kg'},
#   '302': {'Name': 'Barley flour',
#    'quantity': 300,
#    'price': 50,
#    'unit': 'per_kg'},
#   '303': {'Name': 'Jawar flour',
#    'quantity': 500,
#    'price': 50,
#    'unit': 'per_kg'},
#   '304': {'Name': 'Rice', 'quantity': 495, 'price': 50, 'unit': 'per_kg'},
#   '305': {'Name': 'Bajara flour',
#    'quantity': 200,
#    'price': 45,
#    'unit': 'per_kg'}},
#  'Condiments-spices': {'401': {'Name': 'Salt',
#    'quantity': 200,
#    'price': 15,
#    'unit': 'per_kg'},
#   '402': {'Name': 'Sugar', 'quantity': 250, 'price': 40, 'unit': 'per_kg'},
#   '403': {'Name': 'Pepper', 'quantity': 100, 'price': 35, 'unit': 'per_kg'},
#   '404': {'Name': 'Ketchup', 'quantity': 200, 'price': 70, 'unit': 'per_kg'},
#   '405': {'Name': 'Mayonnaise',
#    'quantity': 145,
#    'price': 100,
#    'unit': 'per_kg'}},
#  'Fish-Shelfish': {'501': {'Name': 'Shrimp',
#    'quantity': 200,
#    'price': 100,
#    'unit': 'per_kg'},
#   '502': {'Name': 'Crab', 'quantity': 200, 'price': 120, 'unit': 'per_kg'},
#   '503': {'Name': 'Clams', 'quantity': 200, 'price': 150, 'unit': 'per_kg'},
#   '504': {'Name': 'Tuna', 'quantity': 250, 'price': 80, 'unit': 'per_kg'},
#   '505': {'Name': 'Salmon', 'quantity': 150, 'price': 130, 'unit': 'per_kg'}},
#  'Baverages': {'601': {'Name': 'Water',
#    'quantity': 300,
#    'price': 20,
#    'unit': 'per_Bottle'},
#   '602': {'Name': 'Milk', 'quantity': 200, 'price': 50, 'unit': 'per_Liter'},
#   '603': {'Name': 'Soda',
#    'quantity': 250,
#    'price': 40,
#    'unit': 'per_Bottle 500ml'},
#   '604': {'Name': 'Beer',
#    'quantity': 297,
#    'price': 100,
#    'unit': 'per_Bottle 900ml'},
#   '605': {'Name': 'Oil', 'quantity': 250, 'price': 150, 'unit': 'per_Liter'}}}
